# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,confusion_matrix, roc_curve,precision_recall_curve, average_precision_score

# %%
x_train = np.load(r"../data/cleaned/x_train.npy")
x_test = np.load(r"../data/cleaned/x_test.npy")
x_val = np.load(r"../data/cleaned/x_val.npy")
y_train = np.load(r"../data/cleaned/y_train.npy")
y_test = np.load(r"../data/cleaned/y_test.npy")
y_val = np.load(r"../data/cleaned/y_val.npy")

# %%
def evaluation_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred)

    return accuracy, precision, recall, f1, roc_auc

# %%
results = {"MODEL":[],
            "ACCURACY":[],
            "PRECISION":[],
            "RECALL":[],
            "F1 SCORE":[],
            "AUC":[]}

# %%
def performance(name,acc,precision,recall,f1,auc):
    results["MODEL"].append(name),
    results["ACCURACY"].append(acc),
    results["PRECISION"].append(precision),
    results["RECALL"].append(recall),
    results["F1 SCORE"].append(f1),
    results["AUC"].append(auc)

# %%
'''ann model'''
# Out:
# 'ann model'

# %%
ann_model = keras.models.load_model(r'../models/ann_model_lr.keras')

# %%
y_pred = ann_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy, precision, recall, f1, roc_auc = evaluation_metrics(y_test, y_pred)

# %%
performance("ANN", accuracy, precision, recall, f1, roc_auc)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")      
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.8865
# Precision: 0.8643
# Recall: 0.9180
# F1 Score: 0.8904
# ROC AUC Score: 0.8864

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
confusion_mat
# Out:
# array([[3167,  538],
#        [ 306, 3427]])

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_mat,annot=True,fmt=".2f",cmap="Blues")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.tight_layout()
plt.savefig(r'../static/images/ann-cm.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
'''rnn model'''
# Out:
# 'rnn model'

# %%
rnn_model = keras.models.load_model(r'../models/rnn_model_lr1.keras')

# %%
y_pred = rnn_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step

# %%
accuracy, precision, recall, f1, roc_auc = evaluation_metrics(y_test, y_pred)

# %%
performance("RNN", accuracy, precision, recall, f1, roc_auc)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")      
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.5440
# Precision: 0.5443
# Recall: 0.5609
# F1 Score: 0.5525
# ROC AUC Score: 0.5439

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
confusion_mat
# Out:
# array([[1952, 1753],
#        [1639, 2094]])

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_mat,annot=True,fmt=".2f",cmap="Blues")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.tight_layout()
plt.savefig(r'../static/images/rnn-cm.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
'''lstm'''
# Out:
# 'lstm'

# %%
'''the model name was saved wrong but it was lastm model'''
# Out:
# 'the model name was saved wrong but it was lastm model'

# %%
lstm_model = keras.models.load_model(r'../models/rnn_model_re2.keras')

# %%
y_pred = lstm_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step

# %%
accuracy, precision, recall, f1, roc_auc = evaluation_metrics(y_test, y_pred)

# %%
performance("LSTM", accuracy, precision, recall, f1, roc_auc)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")      
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.8691
# Precision: 0.8717
# Recall: 0.8666
# F1 Score: 0.8692
# ROC AUC Score: 0.8691

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
confusion_mat
# Out:
# array([[3229,  476],
#        [ 498, 3235]])

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_mat,annot=True,fmt=".2f",cmap="Blues")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.tight_layout()
plt.savefig(r'../static/images/lstm-cm.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
'''gru model'''
# Out:
# 'gru model'

# %%
gru_model = keras.models.load_model(r'../models/gru_early.keras')

# %%
y_pred = gru_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step

# %%
accuracy, precision, recall, f1, roc_auc = evaluation_metrics(y_test, y_pred)

# %%
performance("GRU", accuracy, precision, recall, f1, roc_auc)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")      
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.8990
# Precision: 0.8863
# Recall: 0.9164
# F1 Score: 0.9011
# ROC AUC Score: 0.8990

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
confusion_mat
# Out:
# array([[3266,  439],
#        [ 312, 3421]])

# %%
'''bilstm'''
# Out:
# 'bilstm'

# %%
bilstm_model = keras.models.load_model(r'../models/bilstm_seq300.keras')

# %%
y_pred = bilstm_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step

# %%
accuracy, precision, recall, f1, roc_auc = evaluation_metrics(y_test, y_pred)

# %%
performance("BiLSTM", accuracy, precision, recall, f1, roc_auc)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")      
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.8846
# Precision: 0.8714
# Recall: 0.9036
# F1 Score: 0.8872
# ROC AUC Score: 0.8846

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
confusion_mat
# Out:
# array([[3207,  498],
#        [ 360, 3373]])

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_mat,annot=True,fmt=".2f",cmap="Blues")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.tight_layout()
plt.savefig(r'../static/images/bilstm-cm.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
'''visulaization '''
# Out:
# 'visulaization '

# %%
hyper_df = pd.read_csv(r'../log/gru_early.csv')

# %%
plt.figure(figsize=(5, 5))

sns.lineplot( data=hyper_df, x=hyper_df.index + 1, y='accuracy',marker='o', label='Train Accuracy')
sns.lineplot( data=hyper_df, x=hyper_df.index + 1, y='val_accuracy',marker='o', label='Validation Accuracy')

plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=hyper_df, x=hyper_df.index + 1, y='loss',marker='o', label='Train Loss')
sns.lineplot(data=hyper_df, x=hyper_df.index + 1, y='val_loss',marker='o', label='Validation Loss')

plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()

plt.show()

# %%
y_pred = bilstm_model.predict(x_test)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=(10, 8))

sns.heatmap(cm,annot=True,fmt=".2f",cmap="Blues")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.tight_layout()
plt.savefig(r'../static/images/gru-cm.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
y_pred_prob = gru_model.predict(x_test).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

auc_score = roc_auc_score(y_test, y_pred_prob)

print("ROC AUC:", auc_score)
# Out:
# ROC AUC: 0.9593894480890969

# %%
plt.figure(figsize=(8, 6))

plt.plot(fpr,tpr,label=f"GRU (AUC = {auc_score:.4f})")

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="Random Classifier")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - GRU")
def performance(name,acc,precision,recall,f1,auc):
    baseline_performance["MODEL"].append(name),
    baseline_performance["ACCURACY"].append(acc),
    baseline_performance["PRECISION"].append(precision),
    baseline_performance["RECALL"].append(recall),
    baseline_performance["F1 SCORE"].append(f1),
    baseline_performance["AUC"].append(auc)
plt.legend()
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test,y_pred_prob)

ap_score = average_precision_score(y_test,y_pred_prob)

# %%
plt.figure(figsize=(8, 6))

plt.plot(recall,precision,label=f"GRU (AP = {ap_score:.4f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve - GRU")
plt.legend()
plt.grid()

plt.show()

# %%
'''phase 7 comparison of models'''
# Out:
# 'phase 7 comparison of models'

# %%
results
# Out:
# {'MODEL': ['ANN', 'RNN', 'LSTM', 'GRU', 'BiLSTM'],
#  'ACCURACY': [0.8865286367303038,
#   0.5439634310298467,
#   0.8690508201129336,
#   0.8990319978488841,
#   0.8846464103253563],
#  'PRECISION': [0.864312736443884,
#   0.5443202495451,
#   0.8717326866073835,
#   0.8862694300518135,
#   0.8713510720743994],
#  'RECALL': [0.9180283953924457,
#   0.5609429413340477,
#   0.8665952317171176,
#   0.9164211090275918,
#   0.9035628181087597],
#  'F1 SCORE': [0.8903611327617563,
#   0.5525065963060686,
#   0.869156367544331,
#   0.9010931120769129,
#   0.8871646501841136],
#  'AUC': [0.8864096093021607,
#   0.5438992709369294,
#   0.869060098989463,
#   0.8989662900063735,
#   0.8845749313215864]}

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#     MODEL  ACCURACY  PRECISION    RECALL  F1 SCORE       AUC
# 0     ANN  0.886529   0.864313  0.918028  0.890361  0.886410
# 1     RNN  0.543963   0.544320  0.560943  0.552507  0.543899
# 2    LSTM  0.869051   0.871733  0.866595  0.869156  0.869060
# 3     GRU  0.899032   0.886269  0.916421  0.901093  0.898966
# 4  BiLSTM  0.884646   0.871351  0.903563  0.887165  0.884575

# %%
df.to_csv(r"../data/performance/result.csv",index=False)
