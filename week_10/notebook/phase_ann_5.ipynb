# %%
import pandas as pd
import numpy as np

from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
x_train = np.load(r"../data/cleaned/x_train.npy")
x_test = np.load(r"../data/cleaned/x_test.npy")
x_val = np.load(r"../data/cleaned/x_val.npy")
y_train = np.load(r"../data/cleaned/y_train.npy")
y_test = np.load(r"../data/cleaned/y_test.npy")
y_val = np.load(r"../data/cleaned/y_val.npy")

# %%
x_train.shape,x_test.shape,x_val.shape
# Out:
# ((34705, 200), (7438, 200), (7439, 200))

# %%
y_train.shape,y_test.shape,y_val.shape
# Out:
# ((34705,), (7438,), (7439,))

# %%
x_train,x_test,x_val
# Out:
# (array([[    4,    15,    51, ...,     0,     0,     0],
#         [    4,   150,  2060, ...,     0,     0,     0],
#         [  488,    34,     2, ...,     0,     0,     0],
#         ...,
#         [  603,   100,  2577, ...,     0,     0,     0],
#         [  662,  1001,   587, ...,     0,     0,     0],
#         [ 1874, 14608,    44, ...,     0,     0,     0]],
#        shape=(34705, 200), dtype=int32),
#  array([[    5,    25,   493, ...,     0,     0,     0],
#         [  258,   233,  5541, ...,     0,     0,     0],
#         [  617,   573,     1, ...,     1,   937,   971],
#         ...,
#         [   78,  5617, 11034, ...,     0,     0,     0],
#         [  149,   352,   637, ...,     0,     0,     0],
#         [  209,     2,   265, ...,  4748,  6310,   209]],
#        shape=(7438, 200), dtype=int32),
#  array([[ 106,  315,    2, ...,    0,    0,    0],
#         [   3,  415,  627, ...,    0,    0,    0],
#         [2072,  337, 2918, ...,    0,    0,    0],
#         ...,
# ...

# %%
y_train,y_test,y_val
# Out:
# (array([0, 0, 0, ..., 0, 0, 1], shape=(34705,)),
#  array([1, 0, 0, ..., 1, 1, 1], shape=(7438,)),
#  array([1, 1, 0, ..., 1, 0, 0], shape=(7439,)))

# %%
VOCAB_SIZE = 20000
MAX_LEN = 200

# %%
#embediing dimension

# %%
ann_model_em100 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_em100.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = ann_model_em100.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 30s 26ms/step - accuracy: 0.7973 - loss: 0.4250 - val_accuracy: 0.8687 - val_loss: 0.3071
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 27s 25ms/step - accuracy: 0.9008 - loss: 0.2513 - val_accuracy: 0.8511 - val_loss: 0.3528
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 26s 24ms/step - accuracy: 0.9242 - loss: 0.1983 - val_accuracy: 0.8839 - val_loss: 0.3005
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9360 - loss: 0.1715 - val_accuracy: 0.8645 - val_loss: 0.3397
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - accuracy: 0.9492 - loss: 0.1416 - val_accuracy: 0.8912 - val_loss: 0.3085
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.9536 - loss: 0.1256 - val_accuracy: 0.8895 - val_loss: 0.3513
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 30s 27ms/step - accuracy: 0.9585 - loss: 0.1154 - val_accuracy: 0.8801 - val_loss: 0.4029
# Epoch 8/10
# ...

# %%
y_pred = ann_model_em100.predict(x_val)
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_pred = (y_pred >= 0.5).astype(int).ravel()
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8826455168705472
# Precision: 0.8877440347071583
# Recall   : 0.8770425930886686
# F1 Score : 0.8823608678075731
# auc_score : 0.8826659268735302

# %%
#50

# %%
ann_model_em50 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=50
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_em50.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = ann_model_em50.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - accuracy: 0.7822 - loss: 0.4515 - val_accuracy: 0.8231 - val_loss: 0.3898
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.8990 - loss: 0.2553 - val_accuracy: 0.8894 - val_loss: 0.2727
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9208 - loss: 0.2062 - val_accuracy: 0.8648 - val_loss: 0.3363
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9336 - loss: 0.1776 - val_accuracy: 0.8929 - val_loss: 0.2876
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9453 - loss: 0.1514 - val_accuracy: 0.8707 - val_loss: 0.3420
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9489 - loss: 0.1417 - val_accuracy: 0.8532 - val_loss: 0.4176
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.9588 - loss: 0.1173 - val_accuracy: 0.8895 - val_loss: 0.3521
# Epoch 8/10
# ...

# %%
y_pred = ann_model_em50.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8717569565801855
# Precision: 0.8448746587242492
# Recall   : 0.9118671309938388
# F1 Score : 0.8770935325946921
# auc_score : 0.8716108455832658

# %%
#128

# %%
ann_model_em128 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=128
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_em128.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_em128.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.7962 - loss: 0.4206 - val_accuracy: 0.8759 - val_loss: 0.2957
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 41s 38ms/step - accuracy: 0.9011 - loss: 0.2473 - val_accuracy: 0.8864 - val_loss: 0.2783
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 39s 36ms/step - accuracy: 0.9213 - loss: 0.2046 - val_accuracy: 0.8136 - val_loss: 0.4874
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9345 - loss: 0.1740 - val_accuracy: 0.8867 - val_loss: 0.2982
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 39s 36ms/step - accuracy: 0.9457 - loss: 0.1478 - val_accuracy: 0.8437 - val_loss: 0.4601
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9508 - loss: 0.1304 - val_accuracy: 0.8595 - val_loss: 0.4329
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 39s 36ms/step - accuracy: 0.9553 - loss: 0.1203 - val_accuracy: 0.8816 - val_loss: 0.3841
# Epoch 8/10
# ...

# %%
y_pred = ann_model_em128.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8786127167630058
# Precision: 0.9033637400228051
# Recall   : 0.8489150817037235
# F1 Score : 0.8752934677530728
# auc_score : 0.8787208975706962

# %%
#hidden unit

# %%
ann_model_u32 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(32, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_u32.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_u32.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 19ms/step - accuracy: 0.7869 - loss: 0.4445 - val_accuracy: 0.8601 - val_loss: 0.3222
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.8987 - loss: 0.2591 - val_accuracy: 0.8761 - val_loss: 0.2972
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9226 - loss: 0.2055 - val_accuracy: 0.8950 - val_loss: 0.2753
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9397 - loss: 0.1677 - val_accuracy: 0.8796 - val_loss: 0.3290
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9431 - loss: 0.1583 - val_accuracy: 0.8535 - val_loss: 0.3921
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9454 - loss: 0.1480 - val_accuracy: 0.8386 - val_loss: 0.4458
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9553 - loss: 0.1228 - val_accuracy: 0.8919 - val_loss: 0.3521
# Epoch 8/10
# ...

# %%
y_pred = ann_model_u32.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8819733835192902
# Precision: 0.8984091543399386
# Recall   : 0.8623091347441736
# F1 Score : 0.8799890650628759
# auc_score : 0.882045015294375

# %%
#128

# %%
ann_model_u128 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_u128.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_u128.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.8038 - loss: 0.4114 - val_accuracy: 0.8911 - val_loss: 0.2753
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9036 - loss: 0.2412 - val_accuracy: 0.8957 - val_loss: 0.2643
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9189 - loss: 0.2083 - val_accuracy: 0.8454 - val_loss: 0.3461
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9341 - loss: 0.1745 - val_accuracy: 0.8835 - val_loss: 0.3031
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9475 - loss: 0.1435 - val_accuracy: 0.8830 - val_loss: 0.3316
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9497 - loss: 0.1344 - val_accuracy: 0.8931 - val_loss: 0.3267
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9571 - loss: 0.1138 - val_accuracy: 0.8844 - val_loss: 0.4014
# Epoch 8/10
# ...

# %%
y_pred = ann_model_u128.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8678585831428955
# Precision: 0.9171723300970874
# Recall   : 0.8098044468256095
# F1 Score : 0.8601508038127756
# auc_score : 0.868070059354521

# %%
#dropout

# %%
#0.2

# %%
ann_model_drop_2 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_drop_2.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_drop_2.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - accuracy: 0.8030 - loss: 0.4115 - val_accuracy: 0.8857 - val_loss: 0.2840
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9000 - loss: 0.2476 - val_accuracy: 0.8625 - val_loss: 0.3191
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.9210 - loss: 0.2053 - val_accuracy: 0.8459 - val_loss: 0.3702
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.9361 - loss: 0.1695 - val_accuracy: 0.8875 - val_loss: 0.3031
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9438 - loss: 0.1507 - val_accuracy: 0.8929 - val_loss: 0.3102
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9478 - loss: 0.1382 - val_accuracy: 0.8664 - val_loss: 0.3782
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9548 - loss: 0.1200 - val_accuracy: 0.8896 - val_loss: 0.3605
# Epoch 8/10
# ...

# %%
y_pred = ann_model_drop_2.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8283371420889905
# Precision: 0.9330042313117066
# Recall   : 0.7088132869006162
# F1 Score : 0.8056020703303395
# auc_score : 0.8287725365965575

# %%
#0.3

# %%
ann_model_drop_3 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_drop_3.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_drop_3.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - accuracy: 0.8026 - loss: 0.4120 - val_accuracy: 0.7814 - val_loss: 0.4746
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9008 - loss: 0.2489 - val_accuracy: 0.8942 - val_loss: 0.2676
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9257 - loss: 0.1953 - val_accuracy: 0.8941 - val_loss: 0.2763
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9356 - loss: 0.1696 - val_accuracy: 0.8801 - val_loss: 0.3326
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9448 - loss: 0.1464 - val_accuracy: 0.8899 - val_loss: 0.3301
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9519 - loss: 0.1306 - val_accuracy: 0.8532 - val_loss: 0.4453
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9585 - loss: 0.1160 - val_accuracy: 0.8808 - val_loss: 0.3716
# Epoch 8/10
# ...

# %%
y_pred = ann_model_drop_3.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8837209302325582
# Precision: 0.8716951788491446
# Recall   : 0.9008840075006697
# F1 Score : 0.8860492688710315
# auc_score : 0.8836584095787212

# %%
ann_model_drop_3.save(r"../models/ann_model_drop_3.keras")

history_df =pd.DataFrame(history.history)

history_df.to_csv(r'../log/ann_drop_3.csv',index=False)

# %%
#0.5

# %%
ann_model_drop_5 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_drop_5.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_drop_5.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - accuracy: 0.7869 - loss: 0.4313 - val_accuracy: 0.8876 - val_loss: 0.2781
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9024 - loss: 0.2465 - val_accuracy: 0.8758 - val_loss: 0.2944
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9259 - loss: 0.1966 - val_accuracy: 0.8753 - val_loss: 0.3195
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9372 - loss: 0.1718 - val_accuracy: 0.8512 - val_loss: 0.3785
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9425 - loss: 0.1554 - val_accuracy: 0.8908 - val_loss: 0.3163
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9506 - loss: 0.1360 - val_accuracy: 0.8473 - val_loss: 0.4607
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9543 - loss: 0.1227 - val_accuracy: 0.8278 - val_loss: 0.5118
# Epoch 8/10
# ...

# %%
y_pred = ann_model_drop_5.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8850651969350719
# Precision: 0.8929546695794648
# Recall   : 0.8759710688454326
# F1 Score : 0.8843813387423936
# auc_score : 0.8850983244928727

# %%
ann_model_drop_5.save(r"../models/ann_model_drop_5.keras")

history_df =pd.DataFrame(history.history)

history_df.to_csv(r'../log/ann_drop_5.csv',index=False)

# %%
#batch normalization

# %%
ann_model_bn = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_bn.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_bn.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8383 - loss: 0.3676 - val_accuracy: 0.8765 - val_loss: 0.2928
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9057 - loss: 0.2350 - val_accuracy: 0.8886 - val_loss: 0.2770
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.9285 - loss: 0.1817 - val_accuracy: 0.8106 - val_loss: 0.5323
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9381 - loss: 0.1562 - val_accuracy: 0.8789 - val_loss: 0.3447
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9481 - loss: 0.1324 - val_accuracy: 0.8309 - val_loss: 0.4868
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.9553 - loss: 0.1143 - val_accuracy: 0.8312 - val_loss: 0.5683
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.9604 - loss: 0.1050 - val_accuracy: 0.8687 - val_loss: 0.4630
# Epoch 8/10
# ...

# %%
y_pred = ann_model_bn.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8499798359994623
# Precision: 0.9144757681343048
# Recall   : 0.7733726225555854
# F1 Score : 0.8380261248185776
# auc_score : 0.8502588962750944

# %%
#optimizers

# %%
#rms prop

# %%
ann_model_rms = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_rms.compile(optimizer="RMSprop",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_rms.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.5553 - loss: 0.6806 - val_accuracy: 0.7247 - val_loss: 0.5909
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.7546 - loss: 0.5080 - val_accuracy: 0.6763 - val_loss: 0.6074
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.8212 - loss: 0.3953 - val_accuracy: 0.8043 - val_loss: 0.4112
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.8520 - loss: 0.3430 - val_accuracy: 0.8533 - val_loss: 0.3313
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - accuracy: 0.8678 - loss: 0.3138 - val_accuracy: 0.8485 - val_loss: 0.3371
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - accuracy: 0.8820 - loss: 0.2862 - val_accuracy: 0.8841 - val_loss: 0.2828
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.8859 - loss: 0.2762 - val_accuracy: 0.8712 - val_loss: 0.3030
# Epoch 8/10
# ...

# %%
y_pred = ann_model_rms.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.884393063583815
# Precision: 0.9093758905671131
# Recall   : 0.8548084650415215
# F1 Score : 0.8812482739574703
# auc_score : 0.8845008326286938

# %%
ann_model_rms.save(r"../models/ann_model_rms.keras")

history_df =pd.DataFrame(history.history)

history_df.to_csv(r'../log/ann_rms.csv',index=False)

# %%
#sgd

# %%
ann_model_sgd = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_sgd.compile(optimizer="sgd",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_sgd.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5023 - loss: 0.6931 - val_accuracy: 0.5018 - val_loss: 0.6931
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.5026 - loss: 0.6932 - val_accuracy: 0.5155 - val_loss: 0.6930
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5055 - loss: 0.6930 - val_accuracy: 0.5011 - val_loss: 0.6930
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5108 - loss: 0.6930 - val_accuracy: 0.5178 - val_loss: 0.6929
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.5139 - loss: 0.6928 - val_accuracy: 0.5018 - val_loss: 0.6930
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5116 - loss: 0.6928 - val_accuracy: 0.5257 - val_loss: 0.6928
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.5171 - loss: 0.6928 - val_accuracy: 0.5322 - val_loss: 0.6928
# Epoch 8/10
# ...

# %%
y_pred = ann_model_sgd.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.5221131872563517
# Precision: 0.5171088043060361
# Recall   : 0.7206000535762122
# F1 Score : 0.6021264689423615
# auc_score : 0.5213901509111498

# %%
#learning rate

# %%
ann_model_lr_1 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_lr_1.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_lr_1.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 23s 21ms/step - accuracy: 0.7920 - loss: 0.4283 - val_accuracy: 0.8796 - val_loss: 0.2905
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 21ms/step - accuracy: 0.8964 - loss: 0.2582 - val_accuracy: 0.8946 - val_loss: 0.2662
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9243 - loss: 0.2002 - val_accuracy: 0.8824 - val_loss: 0.2936
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9357 - loss: 0.1700 - val_accuracy: 0.8829 - val_loss: 0.3124
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.9513 - loss: 0.1370 - val_accuracy: 0.8773 - val_loss: 0.3599
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 24s 22ms/step - accuracy: 0.9515 - loss: 0.1304 - val_accuracy: 0.8867 - val_loss: 0.3314
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9591 - loss: 0.1122 - val_accuracy: 0.8857 - val_loss: 0.4076
# Epoch 8/10
# ...

# %%
y_pred = ann_model_lr_1.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8757897566877269
# Precision: 0.8489440993788819
# Recall   : 0.9153495847843558
# F1 Score : 0.8808971384377416
# auc_score : 0.8756456504601757

# %%
#lr 0005

# %%
ann_model_lr_2 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_lr_2.compile(optimizer=optimizers.Adam(learning_rate=0.0005),loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_lr_2.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.7796 - loss: 0.4539 - val_accuracy: 0.8712 - val_loss: 0.3078
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.8988 - loss: 0.2541 - val_accuracy: 0.8933 - val_loss: 0.2680
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9202 - loss: 0.2058 - val_accuracy: 0.8938 - val_loss: 0.2667
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9362 - loss: 0.1723 - val_accuracy: 0.8587 - val_loss: 0.3555
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9451 - loss: 0.1496 - val_accuracy: 0.8935 - val_loss: 0.2947
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9536 - loss: 0.1332 - val_accuracy: 0.8628 - val_loss: 0.3805
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9596 - loss: 0.1165 - val_accuracy: 0.8887 - val_loss: 0.3340
# Epoch 8/10
# ...

# %%
y_pred = ann_model_lr_2.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8860061836268316
# Precision: 0.8870405151596459
# Recall   : 0.8856147870345566
# F1 Score : 0.8863270777479892
# auc_score : 0.8860076093834413

# %%
#0001

# %%
ann_model_lr_3 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_lr_3.compile(optimizer=optimizers.Adam(learning_rate=0.0001),loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_lr_3.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - accuracy: 0.6696 - loss: 0.6605 - val_accuracy: 0.7400 - val_loss: 0.5762
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.8368 - loss: 0.4490 - val_accuracy: 0.8500 - val_loss: 0.3774
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.8795 - loss: 0.3175 - val_accuracy: 0.8796 - val_loss: 0.3077
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.8971 - loss: 0.2689 - val_accuracy: 0.8872 - val_loss: 0.2840
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9112 - loss: 0.2366 - val_accuracy: 0.8892 - val_loss: 0.2767
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9193 - loss: 0.2146 - val_accuracy: 0.8947 - val_loss: 0.2667
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.9275 - loss: 0.1964 - val_accuracy: 0.8884 - val_loss: 0.2760
# Epoch 8/10
# ...

# %%
y_pred = ann_model_lr_3.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8917865304476408
# Precision: 0.8700707785642062
# Recall   : 0.9220466113045808
# F1 Score : 0.895304981141891
# auc_score : 0.8916763007953017

# %%
ann_model_lr_3.save(r"../models/ann_model_lr.keras")

history_df =pd.DataFrame(history.history)

history_df.to_csv(r'../log/ann_lr.csv',index=False)

# %%
#rmsprop

# %%
ann_model_lr_4 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_lr_4.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_lr_4.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.5140 - loss: 0.6928 - val_accuracy: 0.5249 - val_loss: 0.6924
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.5459 - loss: 0.6915 - val_accuracy: 0.6236 - val_loss: 0.6899
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.5944 - loss: 0.6874 - val_accuracy: 0.5537 - val_loss: 0.6850
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.6360 - loss: 0.6755 - val_accuracy: 0.6615 - val_loss: 0.6637
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.6972 - loss: 0.6428 - val_accuracy: 0.6845 - val_loss: 0.6200
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.7496 - loss: 0.5779 - val_accuracy: 0.7810 - val_loss: 0.5343
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.7966 - loss: 0.4944 - val_accuracy: 0.8051 - val_loss: 0.4625
# Epoch 8/10
# ...

# %%
y_pred = ann_model_lr_4.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8419142357843796
# Precision: 0.8833583208395802
# Recall   : 0.7891776051433164
# F1 Score : 0.833616298811545
# auc_score : 0.8421063416974003

# %%
#batch size

# %%
ann_model_64 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_64.compile(optimizer="RMSprop",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_64.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.5257 - loss: 0.6914 - val_accuracy: 0.5206 - val_loss: 0.6930
# Epoch 2/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6481 - loss: 0.6353 - val_accuracy: 0.8087 - val_loss: 0.5160
# Epoch 3/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7365 - loss: 0.5276 - val_accuracy: 0.6306 - val_loss: 0.6562
# Epoch 4/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7892 - loss: 0.4494 - val_accuracy: 0.8584 - val_loss: 0.3848
# Epoch 5/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8261 - loss: 0.3904 - val_accuracy: 0.8654 - val_loss: 0.3285
# Epoch 6/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8359 - loss: 0.3653 - val_accuracy: 0.7805 - val_loss: 0.4436
# Epoch 7/10
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8535 - loss: 0.3367 - val_accuracy: 0.8527 - val_loss: 0.3348
# Epoch 8/10
# ...

# %%
y_pred = ann_model_64.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8526683694044899
# Precision: 0.7945052490507036
# Recall   : 0.9528529332976159
# F1 Score : 0.866504263093788
# auc_score : 0.85230342293591

# %%
#16

# %%
ann_model_16 = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_16.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_16.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=16)
# Out:
# Epoch 1/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8053 - loss: 0.4031 - val_accuracy: 0.8228 - val_loss: 0.3937
# Epoch 2/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.9004 - loss: 0.2466 - val_accuracy: 0.8890 - val_loss: 0.2686
# Epoch 3/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.9215 - loss: 0.2031 - val_accuracy: 0.8742 - val_loss: 0.3025
# Epoch 4/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - accuracy: 0.9331 - loss: 0.1748 - val_accuracy: 0.8730 - val_loss: 0.3322
# Epoch 5/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - accuracy: 0.9442 - loss: 0.1481 - val_accuracy: 0.8683 - val_loss: 0.3647
# Epoch 6/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 32s 15ms/step - accuracy: 0.9526 - loss: 0.1285 - val_accuracy: 0.8546 - val_loss: 0.4661
# Epoch 7/10
# 2170/2170 ━━━━━━━━━━━━━━━━━━━━ 32s 15ms/step - accuracy: 0.9567 - loss: 0.1158 - val_accuracy: 0.8312 - val_loss: 0.6257
# Epoch 8/10
# ...

# %%
y_pred = ann_model_16.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8756553300174754
# Precision: 0.9036802760207016
# Recall   : 0.8419501741226896
# F1 Score : 0.8717237553737346
# auc_score : 0.8757781091876266

# %%
#early stopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=3,restore_best_weights=True,verbose=1)

# %%
ann_model_early = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_early.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_early.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32,callbacks=[early_stop])
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 24s 21ms/step - accuracy: 0.7956 - loss: 0.4188 - val_accuracy: 0.8879 - val_loss: 0.2759
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.9013 - loss: 0.2457 - val_accuracy: 0.8720 - val_loss: 0.3027
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9241 - loss: 0.2004 - val_accuracy: 0.8962 - val_loss: 0.2773
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9395 - loss: 0.1643 - val_accuracy: 0.8810 - val_loss: 0.3182
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
y_pred = ann_model_early.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8878881570103508
# Precision: 0.8801468659847889
# Recall   : 0.8990088400750067
# F1 Score : 0.8894778690697058
# auc_score : 0.8878476472366399

# %%
#lr

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2,
    min_lr=1e-6
)

# %%
ann_model_lr = Sequential([
    Input(shape=(MAX_LEN,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(100, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_lr.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_lr.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=32,callbacks=[lr_scheduler])
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 23s 21ms/step - accuracy: 0.9532 - loss: 0.1234 - val_accuracy: 0.8732 - val_loss: 0.3851 - learning_rate: 0.0010
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.9617 - loss: 0.1059 - val_accuracy: 0.8832 - val_loss: 0.3977 - learning_rate: 0.0010
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 21ms/step - accuracy: 0.9669 - loss: 0.0898 - val_accuracy: 0.8345 - val_loss: 0.6830 - learning_rate: 0.0010
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9766 - loss: 0.0634 - val_accuracy: 0.8820 - val_loss: 0.5123 - learning_rate: 5.0000e-04
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.9768 - loss: 0.0611 - val_accuracy: 0.8696 - val_loss: 0.5679 - learning_rate: 5.0000e-04
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 23s 21ms/step - accuracy: 0.9856 - loss: 0.0410 - val_accuracy: 0.8840 - val_loss: 0.5821 - learning_rate: 2.5000e-04
# Epoch 7/10
# ...

# %%
y_pred = ann_model_lr.predict(x_val)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.880494690146525
# Precision: 0.8893756845564075
# Recall   : 0.8700776855076346
# F1 Score : 0.8796208530805687
# auc_score : 0.8805326366016317

# %%
'''seq tuning'''

# %%
x_trainseq = np.load(r"../data/seq/x_train_seq.npy", allow_pickle=True)
x_testseq = np.load(r"../data/seq/x_test_seq.npy", allow_pickle=True)
x_valseq = np.load(r"../data/seq/x_val_seq.npy", allow_pickle=True)

# %%
def create_sequences(length):
    x_train_pad = pad_sequences(
        x_trainseq,
        maxlen=length,
        padding="post",
        truncating="post"
    )

    x_val_pad = pad_sequences(
        x_valseq,
        maxlen=length,
        padding="post",
        truncating="post"
    )

    x_test_pad = pad_sequences(
        x_testseq,
        maxlen=length,
        padding="post",
        truncating="post"
    )
    return x_train_pad, x_val_pad, x_test_pad

# %%
x_train_100, x_val_100, x_test_100 = create_sequences(100)

# %%
print(x_train_100.shape)
print(x_val_100.shape)
print(x_test_100.shape)
# Out:
# (34705, 100)
# (7439, 100)
# (7438, 100)

# %%
ann_model_seq100 = Sequential([
    Input(shape=(100,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])
# Out:
# E0000 00:00:1787590070.938496   31391 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
ann_model_seq100.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_seq100.fit(x_train_100,y_train, validation_data=(x_val_100,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - accuracy: 0.8235 - loss: 0.3947 - val_accuracy: 0.8732 - val_loss: 0.2991
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9074 - loss: 0.2381 - val_accuracy: 0.8726 - val_loss: 0.3044
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9349 - loss: 0.1793 - val_accuracy: 0.8681 - val_loss: 0.3325
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9506 - loss: 0.1357 - val_accuracy: 0.8648 - val_loss: 0.3987
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9618 - loss: 0.1007 - val_accuracy: 0.8455 - val_loss: 0.5510
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9660 - loss: 0.0819 - val_accuracy: 0.8590 - val_loss: 0.5489
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.9720 - loss: 0.0683 - val_accuracy: 0.8548 - val_loss: 0.6632
# Epoch 8/10
# ...

# %%
y_pred = ann_model_seq100.predict(x_val_100)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8525339427342384
# Precision: 0.8616904500548848
# Recall   : 0.8411465309402625
# F1 Score : 0.8512945641859835
# auc_score : 0.8525754241317611

# %%
'''300'''

# %%
x_train_300, x_val_300, x_test_300 = create_sequences(300)

# %%
ann_model_seq300 = Sequential([
    Input(shape=(300,)),
    Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=100
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

# %%
ann_model_seq300.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
history = ann_model_seq300.fit(x_train_300,y_train, validation_data=(x_val_300,y_val),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 22s 19ms/step - accuracy: 0.7375 - loss: 0.4954 - val_accuracy: 0.8790 - val_loss: 0.3063
# Epoch 2/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.8769 - loss: 0.2934 - val_accuracy: 0.8044 - val_loss: 0.4233
# Epoch 3/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9019 - loss: 0.2417 - val_accuracy: 0.8738 - val_loss: 0.3023
# Epoch 4/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9181 - loss: 0.2105 - val_accuracy: 0.8244 - val_loss: 0.4292
# Epoch 5/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9236 - loss: 0.1940 - val_accuracy: 0.8399 - val_loss: 0.3973
# Epoch 6/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9379 - loss: 0.1648 - val_accuracy: 0.9000 - val_loss: 0.2792
# Epoch 7/10
# 1085/1085 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.9424 - loss: 0.1557 - val_accuracy: 0.8767 - val_loss: 0.3494
# Epoch 8/10
# ...

# %%
y_pred = ann_model_seq300.predict(x_val_300)
y_pred = (y_pred >= 0.5).astype(int).ravel()
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
accuracy_ann = accuracy_score(y_val, y_pred)
precision_ann = precision_score(y_val, y_pred)
recall_ann = recall_score(y_val, y_pred)
f1_ann = f1_score(y_val, y_pred)
auc_score = roc_auc_score(y_val, y_pred)

print("Accuracy :", accuracy_ann)
print("Precision:", precision_ann)
print("Recall   :", recall_ann)
print("F1 Score :", f1_ann)
print("auc_score :",auc_score)
# Out:
# Accuracy : 0.8928619438096518
# Precision: 0.8967567567567568
# Recall   : 0.8888293597642647
# F1 Score : 0.8927754607829947
# auc_score : 0.8928766334709073

# %%
ann_model_seq300.save(r"../models/ann_model_seq300.keras")

history_df =pd.DataFrame(history.history)

history_df.to_csv(r'../log/ann_seq300.csv',index=False)
